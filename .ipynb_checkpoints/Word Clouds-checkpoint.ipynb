# %%
# 기본 라이브러리 불러오기
from scipy.misc import imread
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud, ImageColorGenerator
import os
import pandas as pd

# %%
# 파일 이름으로 데이터 불러와서 컬럼명 바꿔주고, 날짜 바꿔주는 함수
# 
def read_data(filename):
    colnames = ['nickname', 'id', 'date', 'tweet']
    path_twt = 'c:/python/workshopd/tweets/'
    data = pd.read_excel(path_twt + filename, header = 0)
    data.columns = colnames
    data['date'] = pd.to_datetime(data['date'], format = '%Y년 %m월 %d일')
    data.reset_index(inplace = True)
    data.drop(['index'], axis = 1, inplace = True)
    return data

# %%
# 
def read_data2(filename):
    colnames = ['nickname', 'id', 'date', 'tweet']
    path_twt = 'c:/python/workshopd/tweets/'
    data = pd.read_excel(path_twt + filename, header = 0)
    data.columns = colnames
    data.reset_index(inplace = True)
    data.drop(['index'], axis = 1, inplace = True)
    return data

# %%
data = read_data2('세월호_2014-04-19.xlsx')

# %%
data['tweet']
# Out:
# 0                            [오마이포토] 세월호 실종자 가족, 청와대로 행진
# 1       獨 권위지 FAZ, 세월호 사고 박근혜에 치명타 -정부의 운명 때론 비정치 사건에서...
# 2       "잠수부들 수백명이 세월호 선내로 들어가 수색했다" 는 등 보도가 난무했지만, 피해...
# 3       국회에제출된법안들잠수시키는 데 이골이난국해의원들이국민 안전관련 법안들을 잠수시키는것...
# 4       세월호 침몰사고는 국정원이 사주한 사고일 가능성 높다  http://durl.me/...
# 5       꼭 들어 보세요 [트위터매거진] 새가 날아든다 - 8회2부.세월호침몰(with신상철...
# 6       암초도 없고, 날씨도 맑고, 파도도 잔잔하고, 수차례 다녀본 익숙한 바닷길이고! 근...
# 7       내용이 띄엄띄엄 있는것같습니다. 뭘 그렇게 숨기는게 많은지...[세월호 침몰] 충격...
# 8       <여객선침몰> 세월호 조타실에선 어떤 일이…(종합2보) http://me2.do/G...
# 9       세월호 관련 잠수함 음모론관련 돌아다니는 사진은 말이 안되는게 잠수함이 찍혔다는 사...
# 10      일본쓰나미사태,원전사태랑 세월호사태 비교해보니까 http://www.ilbe.com...
# 11      선장이나 ..박근혜나...무슨차이?...[세월호 참사]"못 믿을 정부" 폭발한 가족...
# 12      청와대로 행진하는 세월호 피해자 가족: http://ln.is/youtu.be/Iu...
# 13      항로이탈 ㅡ 하부터치ㅡ침수시작.ㅡ급선희 중  조타불능'.?"@moonlover333...
# 14          <여객선침몰> '나홀로 탈출' 세월호 선장 http://zul.im/02oQPO
# 15      실시간 세월호 현장 링크 널리 공유해 주세요 http://m.ustream.tv/c...
# 16      "@snimwj: 새누리당 해산해라 단독]세월호 외면, 새누리당 폭탄주 술판 ‘충격...
# 17      <여객선 세월호 침몰> 조류 약해지는 시간 - 오늘(20일) : 낮 12시 09분,...
# 18      국회의원들이 무슨 대형사건 터질 때마다 무슨 대책위원회를국회에잘도 설치하지만 대책을...
# 19      <세월호침몰사태> 침몰한 여객선 "세월호" 배 안에서, 시신 10구 수습. 사망자 ...
# 20      "@mettayoon: "세월호 = 대한민국, 선장 = 대통령, 선원들 = 고위 공...
# 21                  [팩트TV] 팩트TV&고발뉴스 세월호 사고 공동취재 현장뉴스 3부
# 22      [세월호 참사] '내자식을 살려달라' 행진 http://durl.me/6t9twy ...
# 23      "대참사의 침몰한 페리 세월호가 주는 교훈":http://www.csrdaily.c...
# 24            세월호 생각 | [WP] 서울비블로그 http://bit.ly/1kM64a6
# 25              [세월호 참사]´현장의 진실´ 은폐 급급한 못믿을 정부 - 중앙일보 뉴스
# 26      獨 권위지 FAZ, 세월호 사고 박근혜에 치명타 -정부의 운명 때론 비정치 사건에서...
# 27      과격시위가 걱정됐다면 대표자를 뽑아서 면담을 주선해주고 사태를 진정시키고 질서를 잡...
# 28      나도신이 있는지 없는지 잘모르겠는데 세월호때문에 신이란없다. 신은죽었다 이러는데 지...
# 29      합동수사본부, 세월호와 진도해상관제센터 교신 내용 확보 http://ln.is/me...
#                               ...
# 8856    세월호 사건에 대처하는 현 정부의 행태를 보면 보수정권이 국가안보에 유능하다는 말은...
# 8857    침몰 세월호 주위에 잠수함 추정 물체 발견...도데체 이게 뭘까. http://bb...
# 8858            부활절인 오늘... 세월호 실종자 모두에게 기적이 함께하길 기도합니다...
# 8859    세월호 사건 - 박근혜는 대통령인가 영부인인가? | Daum카페 http://dur...
# 8860                                슬슬 분노가 이네요.  세월호 하...
# 8861    침몰하는 세월호에서 승객보다 먼저 탈출한 혐의를 받고 있는 이준석 선장에게 특정범죄...
# 8862    @1004mingmine 청와대 가는 길에 희희닥 거리며 웃는 세월호 유족들! 이들...
# 8863    세월호 사건이 제2의 5.18이고, 박대통령과 정부가 국민에게 대해 저지른 테러라며...
# 8864    세월호라서 세월 때리고들 있나? 답답한 맘 뿐이네..세월 그만 때리고 얼른 시신이라...
# 8865    "@foxfolf: 세월호 구조대원및 군관 관계자님들 경의를 표합니다.  바다에 잠...
# 8866    뉴욕타임스 17일자,  '세월호 침몰에 희망이 사라지면서 인재의 혐의가 짙어지고 있...
# 8867    "한미연합군사훈련으로 세월호 항로 변경 의혹은 사실 아니다"라고 기상청(@kma_s...
# 8868    "세월호" 세글자만 봐도, 눈물이난다 얘들아 미안하다. 힘들겠지만, 꼭 살아주길 바...
# 8869    세월호 실종가 가족, 총리 면담 요청 연좌농성 http://www.ftoday.co...
# 8870    널리~! RT "@20hope40: CNN, 세월호 물속의 어떤 물체와 부딪혔을 가...
# 8871    "@hee1025w: 독일권위지 FAZ가 세월호사건이 박근혜에게 치명타를준다며,받아...
# 8872    세월호 침몰, 실종자 가족들 진도대교 앞 농성 풀어 - 중앙일보 뉴스 http://...
# 8873    세월호 실종자 가족들에게 죄송합니다. http://helovestory.com/90...
# 8874    RT @indepdnce_ch: 천안함 시즌2 “@jschue1: 사고 직전 "쿵~...
# 8875    [여객선 침몰] 인천시도 세월호 침몰사고로 인천시민 3명이 사망하고 13명이 실종되...
# 8876    세월호 - 대한민국, 선장 - 대통령, 선원들 - 고위 공직자들, 승객 - 국민들,...
# 8877    [여객선 침몰] 세월호 선사인 청해진해운은 오늘 오전 예정된 언론 브리핑 취소, 앞...
# 8878    뉴스타파 보도3 RT"@kty50251: 뉴스타파 - 뉴스타파, 세월호 침몰 상황보...
# 8879    獨 권위지 FAZ, 세월호 사고 박근혜에 치명타 -정부의 운명 때론 비정치 사건에서...
# 8880    @DrPyo 정말 공감되는 말입니다 세월호관련된 기사보면 일베들의 악플도 짜증나지만...
# 8881    [세월호 침몰] 실종자 가족들, “아이를 살려내라” 거리시위...“청와대 가겠다” ...
# 8882      덤벼!! 잡아가줄께!! “@daekeunlee: 세월호 실종자 가족 채증하는 경찰 ”
# 8883    RT "@DrPyo: #Sewol [여객선세월호 침몰사고] '유족충이라니..' 모욕...
# 8884    여객선 침몰사건, 진도 세월호사건 등등 언론에선 "청해진해운"이란 이름을 의도적으로...
# 8885    세월호 시간끌고 티비동원 거짓말 한다고 무능이 덮여질것 같지 않다. 박근혜정권 더이...
# Name: tweet, dtype: object

# %%
import re
regex = r'[가-힣]+'    # 한글만 모조리 불러오자
'\n'.join(re.findall(regex, str(data['tweet'])))
# Out:
# '오마이포토\n세월호\n실종자\n가족\n청와대로\n행진\n권위지\n세월호\n사고\n박근혜에\n치명타\n정부의\n운명\n때론\n비정치\n사건에서\n잠수부들\n수백명이\n세월호\n선내로\n들어가\n수색했다\n는\n등\n보도가\n난무했지만\n피해\n국회에제출된법안들잠수시키는\n데\n이골이난국해의원들이국민\n안전관련\n법안들을\n잠수시키는것\n세월호\n침몰사고는\n국정원이\n사주한\n사고일\n가능성\n높다\n꼭\n들어\n보세요\n트위터매거진\n새가\n날아든다\n회\n부\n세월호침몰\n신상철\n암초도\n없고\n날씨도\n맑고\n파도도\n잔잔하고\n수차례\n다녀본\n익숙한\n바닷길이고\n근\n내용이\n띄엄띄엄\n있는것같습니다\n뭘\n그렇게\n숨기는게\n많은지\n세월호\n침몰\n충격\n여객선침몰\n세월호\n조타실에선\n어떤\n일이\n종합\n보\n세월호\n관련\n잠수함\n음모론관련\n돌아다니는\n사진은\n말이\n안되는게\n잠수함이\n찍혔다는\n사\n일본쓰나미사태\n원전사태랑\n세월호사태\n비교해보니까\n선장이나\n박근혜나\n무슨차이\n세월호\n참사\n못\n믿을\n정부\n폭발한\n가족\n청와대로\n행진하는\n세월호\n피해자\n가족\n항로이탈\n하부터치\n침수시작\n급선희\n중\n조타불능\n여객선침몰\n나홀로\n탈출\n세월호\n선장\n실시간\n세월호\n현장\n링크\n널리\n공유해\n주세요\n새누리당\n해산해라\n단독\n세월호\n외면\n새누리당\n폭탄주\n술판\n충격\n여객선\n세월호\n침몰\n조류\n약해지는\n시간\n오늘\n일\n낮\n시\n분\n국회의원들이\n무슨\n대형사건\n터질\n때마다\n무슨\n대책위원회를국회에잘도\n설치하지만\n대책을\n세월호침몰사태\n침몰한\n여객선\n세월호\n배\n안에서\n시신\n구\n수습\n사망자\n세월호\n대한민국\n선장\n대통령\n선원들\n고위\n공\n팩트\n팩트\n고발뉴스\n세월호\n사고\n공동취재\n현장뉴스\n부\n세월호\n참사\n내자식을\n살려달라\n행진\n대참사의\n침몰한\n페리\n세월호가\n주는\n교훈\n세월호\n생각\n서울비블로그\n세월호\n참사\n현장의\n진실\n은폐\n급급한\n못믿을\n정부\n중앙일보\n뉴스\n권위지\n세월호\n사고\n박근혜에\n치명타\n정부의\n운명\n때론\n비정치\n사건에서\n과격시위가\n걱정됐다면\n대표자를\n뽑아서\n면담을\n주선해주고\n사태를\n진정시키고\n질서를\n잡\n나도신이\n있는지\n없는지\n잘모르겠는데\n세월호때문에\n신이란없다\n신은죽었다\n이러는데\n지\n합동수사본부\n세월호와\n진도해상관제센터\n교신\n내용\n확보\n세월호\n사건에\n대처하는\n현\n정부의\n행태를\n보면\n보수정권이\n국가안보에\n유능하다는\n말은\n침몰\n세월호\n주위에\n잠수함\n추정\n물체\n발견\n도데체\n이게\n뭘까\n부활절인\n오늘\n세월호\n실종자\n모두에게\n기적이\n함께하길\n기도합니다\n세월호\n사건\n박근혜는\n대통령인가\n영부인인가\n카페\n슬슬\n분노가\n이네요\n세월호\n하\n침몰하는\n세월호에서\n승객보다\n먼저\n탈출한\n혐의를\n받고\n있는\n이준석\n선장에게\n특정범죄\n청와대\n가는\n길에\n희희닥\n거리며\n웃는\n세월호\n유족들\n이들\n세월호\n사건이\n제\n의\n이고\n박대통령과\n정부가\n국민에게\n대해\n저지른\n테러라며\n세월호라서\n세월\n때리고들\n있나\n답답한\n맘\n뿐이네\n세월\n그만\n때리고\n얼른\n시신이라\n세월호\n구조대원및\n군관\n관계자님들\n경의를\n표합니다\n바다에\n잠\n뉴욕타임스\n일자\n세월호\n침몰에\n희망이\n사라지면서\n인재의\n혐의가\n짙어지고\n있\n한미연합군사훈련으로\n세월호\n항로\n변경\n의혹은\n사실\n아니다\n라고\n기상청\n세월호\n세글자만\n봐도\n눈물이난다\n얘들아\n미안하다\n힘들겠지만\n꼭\n살아주길\n바\n세월호\n실종가\n가족\n총리\n면담\n요청\n연좌농성\n널리\n세월호\n물속의\n어떤\n물체와\n부딪혔을\n가\n독일권위지\n가\n세월호사건이\n박근혜에게\n치명타를준다며\n받아\n세월호\n침몰\n실종자\n가족들\n진도대교\n앞\n농성\n풀어\n중앙일보\n뉴스\n세월호\n실종자\n가족들에게\n죄송합니다\n천안함\n시즌\n사고\n직전\n쿵\n여객선\n침몰\n인천시도\n세월호\n침몰사고로\n인천시민\n명이\n사망하고\n명이\n실종되\n세월호\n대한민국\n선장\n대통령\n선원들\n고위\n공직자들\n승객\n국민들\n여객선\n침몰\n세월호\n선사인\n청해진해운은\n오늘\n오전\n예정된\n언론\n브리핑\n취소\n앞\n뉴스타파\n보도\n뉴스타파\n뉴스타파\n세월호\n침몰\n상황보\n권위지\n세월호\n사고\n박근혜에\n치명타\n정부의\n운명\n때론\n비정치\n사건에서\n정말\n공감되는\n말입니다\n세월호관련된\n기사보면\n일베들의\n악플도\n짜증나지만\n세월호\n침몰\n실종자\n가족들\n아이를\n살려내라\n거리시위\n청와대\n가겠다\n덤벼\n잡아가줄께\n세월호\n실종자\n가족\n채증하는\n경찰\n여객선세월호\n침몰사고\n유족충이라니\n모욕\n여객선\n침몰사건\n진도\n세월호사건\n등등\n언론에선\n청해진해운\n이란\n이름을\n의도적으로\n세월호\n시간끌고\n티비동원\n거짓말\n한다고\n무능이\n덮여질것\n같지\n않다\n박근혜정권\n더이'

# %%
import re
from konlpy.tag import Twitter

def get_twts(filename):
    data = read_data(filename)
    regex = r'[가-힣]+'    # 한글만 모조리 불러오자
    processed_twt = '\n'.join(re.findall(regex, str(data['tweet'])))
    twt_pos = Twitter().pos(processed_twt, norm = True, stem = True)
    stop_words = ['세월호', '참사', '유가족']
    twt_noun = [''.join(k) for (k, v) in twt_pos if v == 'Noun' and len(k) > 1 and k not in stop_words]
    return ' '.join(twt_noun)

def get_twts2(filename):
    data = read_data2(filename)
    regex = r'[가-힣]+'    # 한글만 모조리 불러오자
    processed_twt = '\n'.join(re.findall(regex, str(data['tweet'])))
    twt_pos = Twitter().pos(processed_twt, norm = True, stem = True)
    twt_noun = [''.join(k) for (k, v) in twt_pos]
    return twt_noun

# %%
get_twts2('세월호_2014-04-19.xlsx')
# Out:
# ['오마이',
#  '포토',
#  '세월호',
#  '실종자',
#  '가족',
#  '청와대로',
#  '행진',
#  '권위',
#  '지',
#  '세월호',
#  '사고',
#  '박근혜',
#  '에',
#  '치명',
#  '타',
#  '정부',
#  '의',
#  '운명',
#  '때론',
#  '비',
#  '정치',
#  '사건',
#  '에서',
#  '잠수부',
#  '들',
#  '수백',
#  '명',
#  '이',
#  '세월호',
#  '서다',
#  '들어가다',
#  '수색',
#  '하다',
#  '늘다',
#  '등',
#  '보도',
#  '가',
#  '난무',
#  '했지만',
#  '피해',
#  '국회',
#  '에',
#  '제출',
#  '되다',
#  '법안',
#  '들',
#  '잠수',
#  '시키다',
#  '데',
#  '이골',
#  '이',
#  '난국',
#  '해',
#  '의원',
#  '들',
#  '이',
#  '국민',
#  '안전',
#  '관련',
#  '법안',
#  '들',
#  '을',
#  '잠수',
#  '시키다',
#  '세월호',
#  '침몰',
#  '사고',
#  '는',
#  '국정원',
#  '이',
#  '사주',
#  '한',
#  '사고',
#  '일',
#  '가능성',
#  '높다',
#  '꼭',
#  '들다',
#  '보다',
#  '트위터',
#  '매다',
#  '새',
#  '가',
#  '날',
#  '아든',
#  '다',
#  '회',
#  '부',
#  '세월호',
#  '침몰',
#  '신상철',
#  '암초',
#  '도',
#  '없다',
#  '날씨',
#  '도',
#  '맑다',
#  '파도',
#  '도',
#  '잔잔',
#  '하고',
#  '수',
#  '차례',
#  '다니다',
#  '보다',
#  '익숙하다',
#  '바닷',
#  '길이',
#  '고',
#  '근',
#  '내용',
#  '이',
#  '띄엄띄엄',
#  '있다',
#  '같다',
#  '뭘',
#  '그렇게',
#  '숨기다',
#  '많다',
#  '세월호',
#  '침몰',
#  '충격',
#  '여객선',
#  '침몰',
#  '세월호',
#  '조타다',
#  '어떻다',
#  '일이',
#  '종합',
#  '보',
#  '세월호',
#  '관련',
#  '잠수함',
#  '음모론',
#  '관련',
#  '돌아다니다',
#  '사진',
#  '은',
#  '말',
#  '이',
#  '안',
#  '되다',
#  '잠수함',
#  '이',
#  '찍히다',
#  '사',
#  '일본',
#  '쓰나미',
#  '사태',
#  '원전',
#  '사태',
#  '랑',
#  '세월호',
#  '사태',
#  '비교',
#  '해보다',
#  '선장',
#  '이나',
#  '박근혜',
#  '나',
#  '무슨',
#  '차이',
#  '세월호',
#  '참사',
#  '못',
#  '믿다',
#  '정부',
#  '폭발',
#  '한',
#  '가족',
#  '청와대로',
#  '행진',
#  '하다',
#  '세월호',
#  '피해자',
#  '가족',
#  '항로',
#  '이탈',
#  '하부',
#  '터치',
#  '침수',
#  '시작',
#  '급',
#  '선희',
#  '중',
#  '조타다',
#  '불능',
#  '여객선',
#  '침몰',
#  '나',
#  '홀로',
#  '탈출',
#  '세월호',
#  '선장',
#  '실시간',
#  '세월호',
#  '현장',
#  '링크',
#  '널리',
#  '공유',
#  '해',
#  '줄다',
#  '새누리당',
#  '해산',
#  '해',
#  '라',
#  '단독',
#  '세월호',
#  '외면',
#  '새누리당',
#  '폭탄주',
#  '술판',
#  '충격',
#  '여객선',
#  '세월호',
#  '침몰',
#  '조류',
#  '약해지다',
#  '시간',
#  '오늘',
#  '일',
#  '낮',
#  '시',
#  '분',
#  '국회의원',
#  '들',
#  '이',
#  '무슨',
#  '대형',
#  '사건',
#  '터지다',
#  '때',
#  '마다',
#  '무슨',
#  '대책',
#  '위원회',
#  '를',
#  '국회',
#  '에',
#  '자다',
#  '설치',
#  '하다',
#  '대책',
#  '을',
#  '세월호',
#  '침몰',
#  '사태',
#  '침몰',
#  '한',
#  '여객선',
#  '세월호',
#  '배',
#  '안',
#  '에서',
#  '시신',
#  '구',
#  '수습',
#  '사망자',
#  '세월호',
#  '대한민국',
#  '선장',
#  '대통령',
#  '선원',
#  '들',
#  '고위',
#  '공',
#  '팩트',
#  '팩트',
#  '고발',
#  '뉴스',
#  '세월호',
#  '사고',
#  '공동',
#  '취재',
#  '현장',
#  '뉴스',
#  '부',
#  '세월호',
#  '참사',
#  '내',
#  '자식',
#  '을',
#  '살리다',
#  '달라',
#  '행진',
#  '대다',
#  '참사',
#  '의',
#  '침몰',
#  '한',
#  '페리',
#  '세월호',
#  '가',
#  '주다',
#  '교훈',
#  '세월호',
#  '생각',
#  '서울',
#  '비',
#  '블로그',
#  '세월호',
#  '참사',
#  '현장',
#  '의',
#  '진실',
#  '은폐',
#  '급',
#  '급',
#  '한',
#  '못',
#  '믿다',
#  '정부',
#  '중앙',
#  '일보',
#  '뉴스',
#  '권위',
#  '지',
#  '세월호',
#  '사고',
#  '박근혜',
#  '에',
#  '치명',
#  '타',
#  '정부',
#  '의',
#  '운명',
#  '때론',
#  '비',
#  '정치',
#  '사건',
#  '에서',
#  '과격',
#  '시위',
#  '가',
#  '걱정',
#  '돼다',
#  '대표자',
#  '를',
#  '뽑다',
#  '면담',
#  '을',
#  '주선',
#  '해주다',
#  '사태',
#  '를',
#  '진정',
#  '시키다',
#  '질서',
#  '를',
#  '잡',
#  '나다',
#  '이',
#  '있다',
#  '없다',
#  '잘',
#  '모르다',
#  '세월호',
#  '때문',
#  '에',
#  '신',
#  '이란',
#  '없다',
#  '신다',
#  '죽다',
#  '이르다',
#  '지다',
#  '합동',
#  '수사',
#  '본부',
#  '세월호',
#  '와',
#  '진도',
#  '해상',
#  '관제',
#  '센터',
#  '교신',
#  '내용',
#  '확보',
#  '세월호',
#  '사건',
#  '에',
#  '대처',
#  '하다',
#  '현',
#  '정부',
#  '의',
#  '행태',
#  '를',
#  '보다',
#  '보수',
#  '정권',
#  '이',
#  '국가',
#  '안보',
#  '에',
#  '유능하다',
#  '말',
#  '은',
#  '침몰',
#  '세월호',
#  '주위',
#  '에',
#  '잠수함',
#  '추정',
#  '물체',
#  '발견',
#  '도데',
#  '체',
#  '이',
#  '게',
#  '뭘',
#  '끄다',
#  '부활절',
#  '인',
#  '오늘',
#  '세월호',
#  '실종자',
#  '모두',
#  '에게',
#  '기적',
#  '이',
#  '함께하다',
#  '기도',
#  '하다',
#  '세월호',
#  '사건',
#  '박근혜',
#  '는',
#  '대통령',
#  '인가',
#  '영부인',
#  '인가',
#  '카페',
#  '슬슬',
#  '분노',
#  '가',
#  '이다',
#  '세월호',
#  '침몰',
#  '하다',
#  '세월호',
#  '에서',
#  '승객',
#  '보다',
#  '먼저',
#  '탈출',
#  '하다',
#  '혐의',
#  '를',
#  '받다',
#  '있다',
#  '이준석',
#  '선장',
#  '에게',
#  '특정',
#  '범죄',
#  '청와대',
#  '가다',
#  '길',
#  '에',
#  '희희닥',
#  '거리',
#  '며',
#  '웃다',
#  '세월호',
#  '유족',
#  '들',
#  '이',
#  '들',
#  '세월호',
#  '사건',
#  '이',
#  '제',
#  '의',
#  '이고',
#  '박',
#  '대통령',
#  '과',
#  '정부',
#  '가',
#  '국민',
#  '에게',
#  '대해',
#  '저지르다',
#  '테러',
#  '라며',
#  '세월호',
#  '라서',
#  '세월',
#  '때리다',
#  '들다',
#  '있다',
#  '답답하다',
#  '맘',
#  '뿐',
#  '이네',
#  '세월',
#  '그만',
#  '때리다',
#  '얼른',
#  '시신',
#  '이라',
#  '세월호',
#  '구조대',
#  '원',
#  '및',
#  '군관',
#  '관계자',
#  '님',
#  '들다',
#  '경의',
#  '를',
#  '표',
#  '하다',
#  '바다',
#  '에',
#  '잠',
#  '뉴욕타임스',
#  '일자',
#  '세월호',
#  '침몰',
#  '에',
#  '희망이',
#  '사라지다',
#  '인재',
#  '의',
#  '혐의',
#  '가',
#  '짙다',
#  '있다',
#  '한미',
#  '연합',
#  '군사훈련',
#  '으로',
#  '세월호',
#  '항로',
#  '변경',
#  '의혹',
#  '은',
#  '사실',
#  '아니다',
#  '라고',
#  '기상청',
#  '세월호',
#  '세',
#  '글자',
#  '만',
#  '봐',
#  '도',
#  '눈물',
#  '이난',
#  '다',
#  '얘',
#  '들',
#  '아',
#  '미안하다',
#  '힘들다',
#  '꼭',
#  '살다',
#  '바',
#  '세월호',
#  '실종',
#  '가',
#  '가족',
#  '총리',
#  '면담',
#  '요청',
#  '연좌농성',
#  '널리',
#  '세월호',
#  '물속',
#  '의',
#  '어떻다',
#  '물체',
#  '와',
#  '부딪히다',
#  '가다',
#  '독일',
#  '권위',
#  '지',
#  '가다',
#  '세월호',
#  '사건',
#  '이',
#  '박근혜',
#  '에게',
#  '치명',
#  '타',
#  '를',
#  '주다',
#  '받다',
#  '세월호',
#  '침몰',
#  '실종자',
#  '가족',
#  '들',
#  '진도대교',
#  '앞',
#  '농성',
#  '풀다',
#  '중앙',
#  '일보',
#  '뉴스',
#  '세월호',
#  '실종자',
#  '가족',
#  '들',
#  '에게',
#  '죄송하다',
#  '천안함',
#  '시즌',
#  '사고',
#  '직전',
#  '쿵',
#  '여객선',
#  '침몰',
#  '인천',
#  '시도',
#  '세월호',
#  '침몰',
#  '사고',
#  '로',
#  '인천',
#  '시민',
#  '명',
#  '이',
#  '사망',
#  '하다',
#  '명',
#  '이',
#  '실종',
#  '되다',
#  '세월호',
#  '대한민국',
#  '선장',
#  '대통령',
#  '선원',
#  '들',
#  '고위',
#  '공직자',
#  '들',
#  '승객',
#  '국민',
#  '들',
#  '여객선',
#  '침몰',
#  '세월호',
#  '선사',
#  '인',
#  '청해진해운',
#  '은',
#  '오늘',
#  '오전',
#  '예정',
#  '되다',
#  '언론',
#  '브리핑',
#  '취소',
#  '앞',
#  '뉴스타파',
#  '보도',
#  '뉴스타파',
#  '뉴스타파',
#  '세월호',
#  '침몰',
#  '상황',
#  '보',
#  '권위',
#  '지',
#  '세월호',
#  '사고',
#  '박근혜',
#  '에',
#  '치명',
#  '타',
#  '정부',
#  '의',
#  '운명',
#  '때론',
#  '비',
#  '정치',
#  '사건',
#  '에서',
#  '정말',
#  '공감',
#  '되다',
#  '말',
#  '이다',
#  '세월호',
#  '관련',
#  '되다',
#  '기사',
#  '보다',
#  '일베',
#  '들',
#  '의',
#  '악플',
#  '도',
#  '짜증',
#  '나',
#  '지만',
#  '세월호',
#  '침몰',
#  '실종자',
#  '가족',
#  '들',
#  '아이',
#  '를',
#  '살리다',
#  '거리',
#  '시위',
#  '청와대',
#  '가다',
#  '덤벼',
#  '잡다',
#  '세월호',
#  '실종자',
#  '가족',
#  '채증',
#  '하다',
#  '경찰',
#  '여객선',
#  '세월호',
#  '침몰',
#  '사고',
#  '유족',
#  '충',
#  '이라니',
#  '모욕',
#  '여객선',
#  '침몰',
#  '사건',
#  '진도',
#  '세월호',
#  '사건',
#  '등등',
#  '언론',
#  '에선',
#  '청해진해운',
#  '이란',
#  '이름',
#  '을',
#  '의도',
#  '적',
#  '으로',
#  '세월호',
#  '시간',
#  '끌',
#  '고',
#  '티비',
#  '동원',
#  '거짓말',
#  '하다',
#  '무능',
#  '이',
#  '덮이다',
#  '것',
#  '같다',
#  '않다',
#  '박근혜',
#  '정권',
#  '더',
#  '이']

# %%
from collections import Counter

# %%
path_twts = 'c:/python/workshopd/tweets/'
os.listdir(path_twts)
# Out:
# ['20141020.xlsx',
#  '20141021.xlsx',
#  '20141022.xlsx',
#  '20141023.xlsx',
#  '20141024.xlsx',
#  '20141025.xlsx',
#  '20141026.xlsx',
#  '20141027.xlsx',
#  '20141029.xlsx',
#  '20141030.xlsx',
#  '20141101.xlsx',
#  '20141102.xlsx',
#  '20141103.xlsx',
#  '20141104.xlsx',
#  '20141105.xlsx',
#  '20141106.xlsx',
#  '20141107.xlsx',
#  '20141109.xlsx',
#  '20141110.xlsx',
#  '20141111.xlsx',
#  '20141112.xlsx',
#  '20141113.xlsx',
#  '20141114.xlsx',
#  '20141115.xlsx',
#  '20141116.xlsx',
#  '20141117.xlsx',
#  '20160104.xlsx',
#  '20160105.xlsx',
#  '20160106.xlsx',
#  '20160107.xlsx',
#  '20160108.xlsx',
#  '20160109.xlsx',
#  '20160110.xlsx',
#  '20160111.xlsx',
#  '20160112.xlsx',
#  '20160113.xlsx',
#  '20160114.xlsx',
#  '20160115.xlsx',
#  '20160116.xlsx',
#  '20160117.xlsx',
#  '세월호_2014-04-16.xlsx',
#  '세월호_2014-04-17.xlsx',
#  '세월호_2014-04-18 .xlsx',
#  '세월호_2014-04-19 .xlsx',
#  '세월호_2014-04-20 .xlsx',
#  '세월호_2014-04-21 .xlsx',
#  '세월호_2014-04-22 .xlsx',
#  '세월호_2014-04-23 .xlsx',
#  '세월호_2015-04-09 .xlsx',
#  '세월호_2015-04-10 .xlsx',
#  '세월호_2015-04-11 .xlsx',
#  '세월호_2015-04-12 .xlsx',
#  '세월호_2015-04-13 .xlsx',
#  '세월호_2015-04-14 .xlsx',
#  '세월호_2015-04-15 .xlsx',
#  '세월호_2015-04-16 .xlsx',
#  '세월호_2015-04-17 .xlsx',
#  '세월호_2015-04-18 .xlsx',
#  '세월호_2015-04-19.xlsx',
#  '세월호_2015-04-20.xlsx',
#  '세월호_2015-04-21.xlsx',
#  '세월호_2015-04-22 .xlsx',
#  '세월호_2015-04-23 .xlsx',
#  '세월호_2016-04-09 .xlsx',
#  '세월호_2016-04-10 .xlsx',
#  '세월호_2016-04-11 .xlsx',
#  '세월호_2016-04-12 .xlsx',
#  '세월호_2016-04-13 .xlsx',
#  '세월호_2016-04-14 .xlsx',
#  '세월호_2016-04-15 .xlsx',
#  '세월호_2016-04-16 .xlsx',
#  '세월호_2016-04-17 .xlsx',
#  '세월호_2016-04-18.xlsx',
#  '세월호_2016-04-19 .xlsx',
#  '세월호_2016-04-20 .xlsx',
#  '세월호_2016-04-21 .xlsx',
#  '세월호_2016-04-22 .xlsx',
#  '세월호_2016-04-23 .xlsx']

# %%
import random

def grey_color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    return "hsl(0, 0%%, %d%%)" % random.randint(60, 100)

def draw_wc(filename, logo_name):
    path_logo = 'c:/python/workshopd/sewol logos/'
    # logo = imread(path_logo + logo_name + '.jpg')
    # image_color = ImageColorGenerator(logo)
    data = get_twts(filename)
    wc = WordCloud(width = 1920, height = 1280, font_path = "C:\Windows\Fonts\YoonGothic750.otf",
               background_color = "white", ranks_only = True,
               color_func = grey_color_func, max_words = 500)
    wc.generate(data)
    plt.axis('off')
    plt.imshow(wc.recolor(color_func=grey_color_func, random_state=3))
    return wc.to_file(filename[:-5] + '.png')

# %%
draw_wc('20141110.xlsx', 'color base')

# %%
draw_wc('20141027.xlsx', '세월호1')

# %%
def draw_wc3(filename):
    data = get_twts(filename)
    wc = WordCloud(width = 1920, height = 1280, font_path = "C:\Windows\Fonts\YoonGothic750.otf",
               background_color = "white", ranks_only = False, margin = 10,
               max_words = 500)
    wc.generate(data)
    plt.axis('off')
    plt.imshow(wc)
    return plt.savefig(filename[:-5] + '.svg', format = 'svg')

# %%
draw_wc('20141110.xlsx', '세월호1')

# %%
import os
path = 'C:/python/workshopd/tweets/'
files = os.listdir(path)

# %%
path_logo = 'c:/python/workshopd/sewol logos/'
logo1 = imread(path_logo + '세월호3.jpg')

image_color1 = ImageColorGenerator(logo1)

twt_pos3 = get_twts('20141027.xlsx')

wc1 = WordCloud(width = 1920, height = 1280, font_path="C:\Windows\Fonts\맑은고딕\malgunbd.ttf",
               background_color = "black", mask = logo1, ranks_only = True,
               color_func = image_color1, max_font_size = 10, max_words = 500)
wc1.generate(twt_pos3)
plt.axis('off')
plt.imshow(wc1)
